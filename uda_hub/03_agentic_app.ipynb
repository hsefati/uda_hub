# %% [markdown]
# ## Setup

# %%
from dotenv import load_dotenv
from utils import chat_interface

# %%
load_dotenv()
# Out:
# True

# %%
from agentic.workflow import app as orchestrator
# Out:
# 🎨 Workflow diagram updated: 'uda_hub_workflow.png'

# %% [markdown]
# ## Run Nr.1 with existing Users

# %% [markdown]
# Request: I want to know what's included in my CultPass. My email is bob.stone@granite.com

# %%
chat_interface(orchestrator, "bob")
#"I want to know what's included in my CultPass. My email is bob.stone@granite.com"
# Out:
# --- UDA-Hub Session Started (Thread: bob) ---
# [CONCIERGE] triage_intent=support_request is_identified=True has_response=False
# [ENRICHER] user_id=f556c0 user_email=bob.stone@granite.com customer_tier=basic
# [HISTORIAN] user_id=f556c0 is_recurring=False suggested_action=proceed
# [CLASSIFIER] category=general_inquiry urgency=standard confidence=0.90
# [SUPERVISOR] route=researcher reason=automation_default
# [TOOL_SEARCH_KNOWLEDGE_BASE] query=CultPass
# [TOOL_CHECK_RESERVATIONS] user_id=f556c0
# [TOOL_CHECK_RESERVATIONS_RESULT] user_id=f556c0 found=True matches=2
# [TOOL_SEARCH_KNOWLEDGE_BASE_RESULT] query=CultPass found=True matches=7
# [TOOL_SEARCH_KNOWLEDGE_BASE] query=CultPass
# [TOOL_CHECK_RESERVATIONS] user_id=f556c0
# [TOOL_CHECK_RESERVATIONS_RESULT] user_id=f556c0 found=True matches=2
# [TOOL_SEARCH_KNOWLEDGE_BASE_RESULT] query=CultPass found=True matches=7
# ✅ RESEARCH GATE: High confidence (0.95). Proceeding to Drafter.
# [DRAFTER] ai_response_present=True
# ...

# %%
list(orchestrator.get_state_history(
    config = {
        "configurable": {
            "thread_id": "bob",
        }
    }
))[0].values["messages"]
# Out:
# [HumanMessage(content="I want to know what's included in my CultPass. My email is bob.stone@granite.com", additional_kwargs={}, response_metadata={}, id='2303b092-f2d0-4e8a-9628-dfa92edeb95b'),
#  AIMessage(content="Hello Bob,\n\nThank you for reaching out about your CultPass subscription. As a Basic tier subscriber, your CultPass includes four cultural experiences per month. These can range from art exhibitions and museum entries to music concerts and film screenings. Please note that some premium experiences might require an additional fee, which will be clearly indicated in the app.\n\nIf you have any further questions or need assistance with your reservations, feel free to let me know. I'm here to help!\n\nBest regards,  \n[Your Name]", additional_kwargs={}, response_metadata={}, id='c3af976a-9bfd-42c7-b9e7-8783490d288a', tool_calls=[], invalid_tool_calls=[])]

# %% [markdown]
# ## Run Nr.2 with existing Users

# %% [markdown]
# Request: I'm locked out of my account and the magic link isn't working, can you help frank.ocean@seawaves.io?

# %%
chat_interface(orchestrator, "Frank")
# Out:
# --- UDA-Hub Session Started (Thread: Frank) ---
# [CONCIERGE] triage_intent=support_request is_identified=True has_response=False
# [ENRICHER] user_id=e6376d user_email=frank.ocean@seawaves.io customer_tier=basic
# [HISTORIAN] user_id=e6376d is_recurring=False suggested_action=proceed
# [CLASSIFIER] category=technical_issue urgency=standard confidence=0.90
# [SUPERVISOR] route=researcher reason=automation_default
# [TOOL_SEARCH_KNOWLEDGE_BASE] query=login
# [TOOL_CHECK_RESERVATIONS] user_id=e6376d
# [TOOL_CHECK_RESERVATIONS_RESULT] user_id=e6376d found=True matches=2
# [TOOL_SEARCH_KNOWLEDGE_BASE_RESULT] query=login found=True matches=2
# [TOOL_SEARCH_KNOWLEDGE_BASE] query=login
# [TOOL_CHECK_RESERVATIONS] user_id=e6376d
# [TOOL_SEARCH_KNOWLEDGE_BASE_RESULT] query=login found=True matches=2
# [TOOL_CHECK_RESERVATIONS_RESULT] user_id=e6376d found=True matches=2
# ✅ RESEARCH GATE: High confidence (0.95). Proceeding to Drafter.
# [DRAFTER] ai_response_present=True
# ...

# %%
list(orchestrator.get_state_history(
    config = {
        "configurable": {
            "thread_id": "Frank",
        }
    }
))[0].values["messages"]
# Out:
# [HumanMessage(content="I'm locked out of my account and the magic link isn't working, can you help frank.ocean@seawaves.io?", additional_kwargs={}, response_metadata={}, id='8241da9f-ec66-4bad-9a9e-844d6898078d'),
# ...

# %% [markdown]
# ## Run Nr.3 without existing Users

# %% [markdown]
# Request: I'm trying to book the Samba Night in Lapa for next week but the app keeps crashing when I hit reserve.

# %%
chat_interface(orchestrator, "unknown_user")
# Out:
# --- UDA-Hub Session Started (Thread: unknown_user) ---
# [CONCIERGE] triage_intent=need_user_response is_identified=False has_response=True
# Assistant: I can help you with that! Could you please provide your email or name so I can assist you further?
# [CONCIERGE] triage_intent=support_request is_identified=True has_response=False
# [ENRICHER] full_name="Pedro Pascal" customer_tier=unknown
# [CLASSIFIER] category=technical_issue urgency=standard confidence=0.90
# [SUPERVISOR] route=researcher reason=automation_default
# [TOOL_SEARCH_KNOWLEDGE_BASE] query=booking
# [TOOL_SEARCH_KNOWLEDGE_BASE_RESULT] query=booking found=True matches=1
# [TOOL_SEARCH_KNOWLEDGE_BASE] query=tier
# [TOOL_SEARCH_KNOWLEDGE_BASE_RESULT] query=tier found=False matches=0
# [TOOL_SEARCH_KNOWLEDGE_BASE] query=tier
# [TOOL_SEARCH_KNOWLEDGE_BASE_RESULT] query=tier found=False matches=0
# 🚨 RESEARCH GATE: Low confidence (0.3). Forcing Escalation.
# ...

# %%
list(orchestrator.get_state_history(
    config = {
        "configurable": {
            "thread_id": "unknown_user",
        }
    }
))[0].values["messages"]
# Out:
# [HumanMessage(content="I'm trying to book the Samba Night in Lapa for next week but the app keeps crashing when I hit reserve.", additional_kwargs={}, response_metadata={}, id='9e220ed2-a457-4b54-bc8e-ef3e14352b6d'),
#  HumanMessage(content='Pedro Pascal', additional_kwargs={}, response_metadata={}, id='2d100fc5-202e-43de-9daa-f91de284dfc0'),
#  AIMessage(content="I've reviewed your request regarding technical_issue. Because this requires specialized assistance to ensure everything is handled correctly, I am handing this over to one of our human experts. They will be with you shortly!", additional_kwargs={}, response_metadata={}, id='c7556664-f14f-40b7-8ed3-4c5014cbab12', tool_calls=[], invalid_tool_calls=[])]
