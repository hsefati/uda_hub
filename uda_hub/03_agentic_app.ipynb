# %% [markdown]
# ## Setup

# %%
from dotenv import load_dotenv
from utils import chat_interface

# %%
load_dotenv()
# Out:
# True

# %%
from agentic.workflow import app as orchestrator
# Out:
# 🎨 Workflow diagram updated: 'uda_hub_workflow.png'

# %% [markdown]
# ## Run Nr.1 with existing Users

# %% [markdown]
# Requests: I can't attend my Christ the Redeemer booking. Refund?. My email is alice.kingsley@wonderland.com.

# %%
chat_interface(orchestrator, "Alice")
# Out:
# --- UDA-Hub Session Started (Thread: Alice) ---
# [CONCIERGE] triage_intent=support_request is_identified=True has_response=False
# [ENRICHER] user_id=a4ab87 user_email=alice.kingsley@wonderland.com customer_tier=premium
# [HISTORIAN] user_id=a4ab87 is_recurring=False suggested_action=proceed
# [CLASSIFIER] category=billing urgency=high confidence=0.95
# [SUPERVISOR] route=escalator reason=urgency_or_low_confidence
# [ESCALATOR] retrieval_confidence=0.00 handoff_summary="**Reason for Escalation:** Knowledge Retrieval Failure
# **Retrieval Confidence:** 0.0
# **Customer Context:** Premium &" status=pending_human
# [ARCHIVIST] ticket_id=7ca7a45b-aadc-48bd-b64a-c94af24c640e archived=True
# Assistant: I've reviewed your request regarding billing. Because this requires specialized assistance to ensure everything is handled correctly, I am handing this over to one of our human experts. They will be with you shortly!

# %%
list(orchestrator.get_state_history(
    config = {
        "configurable": {
            "thread_id": "Alice",
        }
    }
))[0].values["messages"]
# Out:
# [HumanMessage(content="I can't attend my Christ the Redeemer booking. Refund?. My email is alice.kingsley@wonderland.com.", additional_kwargs={}, response_metadata={}, id='9685d787-f729-4f2f-ac01-96c06bd16a22'),
#  AIMessage(content="I've reviewed your request regarding billing. Because this requires specialized assistance to ensure everything is handled correctly, I am handing this over to one of our human experts. They will be with you shortly!", additional_kwargs={}, response_metadata={}, id='37b5e877-308a-483b-bdeb-f12a762c56fd', tool_calls=[], invalid_tool_calls=[])]

# %% [markdown]
# ## Run Nr.2 with existing Users

# %% [markdown]
# Request: I'm locked out of my account and the magic link isn't working, can you help frank.ocean@seawaves.io?

# %%
chat_interface(orchestrator, "Frank")
# Out:
# --- UDA-Hub Session Started (Thread: Frank) ---
# [CONCIERGE] triage_intent=support_request is_identified=True has_response=False
# [ENRICHER] user_id=e6376d user_email=frank.ocean@seawaves.io customer_tier=premium
# [HISTORIAN] user_id=e6376d is_recurring=False suggested_action=proceed
# [CLASSIFIER] category=technical_issue urgency=high confidence=0.95
# [SUPERVISOR] route=escalator reason=urgency_or_low_confidence
# [ESCALATOR] retrieval_confidence=0.00 handoff_summary="**Reason for Escalation:** Knowledge Retrieval Failure
# **Retrieval Confidence:** 0.0
# **Customer Context:** Tier=prem" status=pending_human
# [ARCHIVIST] ticket_id=b47bd69c-83c9-4eba-8f47-3e9adf4c7e5c archived=True
# Assistant: I've reviewed your request regarding technical_issue. Because this requires specialized assistance to ensure everything is handled correctly, I am handing this over to one of our human experts. They will be with you shortly!

# %%
list(orchestrator.get_state_history(
    config = {
        "configurable": {
            "thread_id": "Alice",
        }
    }
))[0].values["messages"]
# Out:
# [HumanMessage(content="I can't attend my Christ the Redeemer booking. Refund?. My email is alice.kingsley@wonderland.com.", additional_kwargs={}, response_metadata={}, id='9685d787-f729-4f2f-ac01-96c06bd16a22'),
#  AIMessage(content="I've reviewed your request regarding billing. Because this requires specialized assistance to ensure everything is handled correctly, I am handing this over to one of our human experts. They will be with you shortly!", additional_kwargs={}, response_metadata={}, id='37b5e877-308a-483b-bdeb-f12a762c56fd', tool_calls=[], invalid_tool_calls=[])]

# %% [markdown]
# ## Run Nr.3 without existing Users

# %% [markdown]
# Request: I'm trying to book the Samba Night in Lapa for next week but the app keeps crashing when I hit reserve.

# %%
chat_interface(orchestrator, "unknown_user")
# Out:
# --- UDA-Hub Session Started (Thread: unknown_user) ---
# [CONCIERGE] triage_intent=need_user_response is_identified=False has_response=True
# Assistant: I understand you're having trouble booking the Samba Night in Lapa. Could you please provide your email or name so I can assist you further?
# [CONCIERGE] triage_intent=support_request is_identified=True has_response=False
# [ENRICHER] full_name="James Pedro" customer_tier=unknown
# [CLASSIFIER] category=account_management urgency=standard confidence=0.90
# [SUPERVISOR] route=researcher reason=automation_default
# [RESEARCHER] retrieval_confidence=0.60
# 🚨 RESEARCH GATE: Low confidence (0.6). Forcing Escalation.
# [ESCALATOR] retrieval_confidence=0.60 handoff_summary="**Reason for Escalation:** Knowledge Retrieval Failure
# **Retrieval Confidence:** 0.6
# **Customer Context:** Tier=unkn" status=pending_human
# ⏸️ Archivist: Bypassing archive (Anonymous session).
# Assistant: I've reviewed your request regarding account_management. Because this requires specialized assistance to ensure everything is handled correctly, I am handing this over to one of our human experts. They will be with you shortly!

# %%
list(orchestrator.get_state_history(
    config = {
        "configurable": {
            "thread_id": "unknown_user",
        }
    }
))[0].values["messages"]
# Out:
# [HumanMessage(content="I'm trying to book the Samba Night in Lapa for next week but the app keeps crashing when I hit reserve.", additional_kwargs={}, response_metadata={}, id='2d352558-c26e-4800-9cd4-f2df1bf87580'),
#  HumanMessage(content='James Pedro', additional_kwargs={}, response_metadata={}, id='da9af2d7-b53b-4da7-aad6-500e4ff08685'),
#  AIMessage(content="I've reviewed your request regarding account_management. Because this requires specialized assistance to ensure everything is handled correctly, I am handing this over to one of our human experts. They will be with you shortly!", additional_kwargs={}, response_metadata={}, id='8f0c6b47-63f2-457f-a42a-c9779eed8e50', tool_calls=[], invalid_tool_calls=[])]
