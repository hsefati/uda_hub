# %% [markdown]
# ## Setup

# %%
from dotenv import load_dotenv
from utils import chat_interface

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Run

# %%
# IDEALLY YOUR ONLY IMPORT HERE IS:
# from agentic.workflow import orchestrator

from agentic.workflow import app as orchestrator
# Out:
# Workflow diagram saved as 'uda_hub_workflow.png'

# %%
chat_interface(orchestrator, "1")
# Out:
# User: I can't attend my Christ the Redeemer booking. Refund?
# Assistant: Thank you for reaching out! Could you please provide the email address associated with your account so we can look it up?
# User: sure, my email address: alice.kingsley@wonderland.com
# Assistant: Hello Alice,
#
# Thank you for reaching out to us. I apologize for any inconvenience you may be experiencing. Unfortunately, we're currently facing a database error that is preventing us from accessing reservation details and other related information.
#
# Please rest assured that our technical team is actively working to resolve this issue as quickly as possible. In the meantime, if there's anything else I can assist you with or if you have any specific questions, please let me know, and I'll do my best to help.
#
# Thank you for your patience and understanding.
#
# Best regards,
#
# [Your Name]
# [Your Position]

# %%
list(orchestrator.get_state_history(
    config = {
        "configurable": {
            "thread_id": "1",
        }
    }
))[0].values["messages"]
